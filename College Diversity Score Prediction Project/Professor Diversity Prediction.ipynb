# %%
# Import packages
import numpy as np
import pandas as pd
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error,mean_absolute_error
import sys

# %%
# Generate the training data set
df_lac_training = pd.read_csv('Liberal Arts College/df_lac_prof_diversity_training.csv')

# %%
df_lac_training.head()
# Out:
#    ipeds_id                     uni_name state school_year  ranking  hbcu  \
# 0  100937.0  Birmingham Southern College    AL   2013-2014      124   0.0
# 1  100937.0  Birmingham Southern College    AL   2013-2014      124   0.0
# 2  100937.0  Birmingham Southern College    AL   2013-2014      124   0.0
# 3  100937.0  Birmingham Southern College    AL   2013-2014      124   0.0
# 4  100937.0  Birmingham Southern College    AL   2013-2014      124   0.0
#
#    pct_retention  stu_faculty_ratio  beg_endowment  end_endowment  ...  \
# 0           80.0               13.0     50042970.0     53921439.0  ...
# 1           80.0               13.0     50042970.0     53921439.0  ...
# 2           80.0               13.0     50042970.0     53921439.0  ...
# 3           80.0               13.0     50042970.0     53921439.0  ...
# 4           80.0               13.0     50042970.0     53921439.0  ...
#
#    gradrate_asia  gradrate_bkaa  gradrate_hisp  gradrate_nhpi  gradrate_whit  \
# 0         2.9289         5.0209         0.8368            0.0        89.1213
# 1         2.9289         5.0209         0.8368            0.0        89.1213
# 2         2.9289         5.0209         0.8368            0.0        89.1213
# 3         2.9289         5.0209         0.8368            0.0        89.1213
# 4         2.9289         5.0209         0.8368            0.0        89.1213
#
#    gradrate_2mor  gradrate_unkn  gradrate_intl  pct_female_prof_salary  \
# 0         1.2552         0.4184            0.0                 0.36277
# 1         1.2552         0.4184            0.0                 0.36277
# 2         1.2552         0.4184            0.0                 0.36277
# 3         1.2552         0.4184            0.0                 0.36277
# 4         1.2552         0.4184            0.0                 0.36277
#
#    pct_male_prof_salary
# 0               0.63723
# 1               0.63723
# 2               0.63723
# 3               0.63723
# 4               0.63723
#
# [5 rows x 50 columns]

# %%
# Generate the test data set
# 2021-2022 AS TEST SET
df_lac_test = pd.read_csv('Liberal Arts College/df_lac_prof_diversity_test.csv')

# %%
# Import df
df_lac = pd.read_csv('Liberal Arts College/df_lac_final.csv')

# %%
# I. Summary Statistics for Top Universities Based on 2025 Best National University Rankings

# %%
# Top 5 Universities Based on 2025 Best Liberal Arts College Rankings + Dickinson
df_top_uni = df_lac[df_lac['uni_name'].isin(['Williams College',
                                           'Amherst College',
                                           'Amherst College',
                                           'Bowdoin College',
                                           'Pomona College',
                                           'Dickinson College'])]

# %%
# Extract the starting year to sort
df_top_uni.loc[:, 'year_start'] = df_lac['school_year'].str.split('-').str[0].astype(int)

# Sort the data by starting year
df_top_uni = df_top_uni.sort_values('year_start')

# Plot
plt.figure(figsize=(10, 6))
for uni in df_top_uni['uni_name'].unique():
    uni_data = df_top_uni[df_top_uni['uni_name'] == uni]
    plt.scatter(uni_data['school_year'], uni_data['prof_diversity'], label=uni)
    plt.plot(uni_data['school_year'], uni_data['prof_diversity'])

plt.xlabel('School Year')
plt.ylabel('Professor Diversity')
plt.title('Professor Diversity Over School Years by College')
plt.legend(title='College')
plt.xticks(rotation=45)
plt.tight_layout()

# Save the figure as a PNG file with higher DPI
plt.savefig(f'Top 5 Colleges Based on 2025 Best Liberal Arts College Rankings (Professor Diversity).png', format='png', dpi=300)

plt.show()
# Out:
# /var/folders/bc/cq3wb6t53dzfk32y587l32kw0000gn/T/ipykernel_49673/662490793.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_top_uni.loc[:, 'year_start'] = df_lac['school_year'].str.split('-').str[0].astype(int)

# %%
# II. Machine Learning Model
## Dependent Variable: stu_diversity

# %%
## A. The Training Set

# %%
# Create Pandas Dataframe
y_train = pd.DataFrame()
X_train = pd.DataFrame()

# Prepare the training set features
X_train = pd.get_dummies(df_lac_training['state'], drop_first=True)

# Add other variables
dict_var = ['ranking', 'hbcu', 'pct_retention', 'stu_faculty_ratio', 
              'beg_endowment', 'stu_financial_aid', 'stu_diversity', 'prop_major', 
              'pct_female_stu', 'pct_male_stu', 'gradrate_female', 'gradrate_male', 
              'pct_female_prof_salary', 'pct_male_prof_salary']

for var in dict_var:
    X_train[var] = df_lac_training[var]

# Target variable
y_train = df_lac_training['prof_diversity']

# Add constant to the training set
X_train = sm.add_constant(X_train)

# Fit the model on the training data
model = sm.OLS(y_train, X_train).fit()

# Print the summary of the model
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         prof_diversity   R-squared:                       0.724
# Model:                            OLS   Adj. R-squared:                  0.724
# Method:                 Least Squares   F-statistic:                     3061.
# Date:                Wed, 18 Dec 2024   Prob (F-statistic):               0.00
# Time:                        11:31:12   Log-Likelihood:            -1.7963e+05
# No. Observations:               54772   AIC:                         3.594e+05
# Df Residuals:                   54724   BIC:                         3.598e+05
# Df Model:                          47
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                  -1145.1277    160.520     -7.134      0.000   -1459.749    -830.507
# AR                        -2.7506      0.511     -5.387      0.000      -3.751      -1.750
# CA                        11.1419      0.435     25.631      0.000      10.290      11.994
# CO                        12.3783      0.544     22.750      0.000      11.312      13.445
# CT                         6.4765      0.467     13.864      0.000       5.561       7.392
# FL                         8.9621      0.496     18.056      0.000       7.989       9.935
# GA                        -2.2098      0.471     -4.694      0.000      -3.133      -1.287
# IA                         2.5752      0.430      5.982      0.000       1.731       3.419
# ID                        -5.0864      0.562     -9.057      0.000      -6.187      -3.986
# IL                         2.9383      0.429      6.846      0.000       2.097       3.780
# IN                         5.0852      0.438     11.618      0.000       4.227       5.943
# KY                        -0.5016      0.456     -1.100      0.271      -1.396       0.392
# LA                        -0.6269      0.628     -0.999      0.318      -1.857       0.603
# MA                         5.9758      0.432     13.845      0.000       5.130       6.822
# MD                         2.6402      0.466      5.667      0.000       1.727       3.553
# ME                         7.0870      0.456     15.538      0.000       6.193       7.981
# MI                         9.3880      0.436     21.554      0.000       8.534      10.242
# MN                         3.4330      0.431      7.970      0.000       2.589       4.277
# MO                         3.2146      0.489      6.568      0.000       2.255       4.174
# MS                         3.4352      0.545      6.307      0.000       2.368       4.503
# NC                         7.0979      0.449     15.793      0.000       6.217       7.979
# NE                        -4.0156      0.582     -6.902      0.000      -5.156      -2.875
# NH                         5.8625      0.532     11.011      0.000       4.819       6.906
# NJ                        10.9795      0.616     17.812      0.000       9.771      12.188
# NM                       -13.2202      1.914     -6.906      0.000     -16.972      -9.468
# NY                         3.9842      0.429      9.288      0.000       3.143       4.825
# OH                         5.6840      0.432     13.154      0.000       4.837       6.531
# OR                         4.1683      0.457      9.114      0.000       3.272       5.065
# PA                         4.2720      0.419     10.200      0.000       3.451       5.093
# SC                         3.0461      0.466      6.537      0.000       2.133       3.959
# TN                         6.6981      0.479     13.980      0.000       5.759       7.637
# TX                         3.5277      0.492      7.171      0.000       2.564       4.492
# VA                         1.5253      0.430      3.550      0.000       0.683       2.367
# VT                         5.5311      0.443     12.472      0.000       4.662       6.400
# WA                        10.4755      0.475     22.054      0.000       9.544      11.406
# WI                         4.4015      0.435     10.119      0.000       3.549       5.254
# WV                        52.9502      1.314     40.310      0.000      50.376      55.525
# ranking                   -0.0417      0.001    -29.775      0.000      -0.044      -0.039
# hbcu                      45.7802      0.413    110.856      0.000      44.971      46.590
# pct_retention              0.1707      0.008     22.343      0.000       0.156       0.186
# stu_faculty_ratio         -0.2373      0.027     -8.650      0.000      -0.291      -0.184
# beg_endowment          -1.538e-09   9.64e-11    -15.959      0.000   -1.73e-09   -1.35e-09
# stu_financial_aid          0.0007   5.69e-05     12.923      0.000       0.001       0.001
# stu_diversity              0.4053      0.003    129.015      0.000       0.399       0.411
# prop_major                -0.0085      0.004     -2.347      0.019      -0.016      -0.001
# pct_female_stu          5.912e+04   8287.888      7.134      0.000    4.29e+04    7.54e+04
# pct_male_stu            5.912e+04   8287.888      7.134      0.000    4.29e+04    7.54e+04
# gradrate_female        -5.911e+04   8285.454     -7.134      0.000   -7.53e+04   -4.29e+04
# gradrate_male          -5.911e+04   8285.455     -7.134      0.000   -7.53e+04   -4.29e+04
# pct_female_prof_salary  -593.2367     82.851     -7.160      0.000    -755.626    -430.847
# pct_male_prof_salary    -588.9073     82.858     -7.107      0.000    -751.310    -426.504
# ==============================================================================
# Omnibus:                    20687.316   Durbin-Watson:                   0.015
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           246889.220
# Skew:                           1.479   Prob(JB):                         0.00
# Kurtosis:                      12.972   Cond. No.                     2.29e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.56e-13. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Redirect the summary output to a file
with open('model_summary_prof_diversity.txt', 'w') as f:
    # Capture the output and write it to the file
    sys.stdout = f
    print(model.summary())
    sys.stdout = sys.__stdout__  # Reset redirect
# Out:
# Mean Squared Error (MSE): 0.11412846255461657
# Mean Absolute Error (MAE): 0.33246837013500513
# [  1.  44.  84. 127. 166.]
# Mean Squared Error (MSE): 635.2821506286618
# Mean Absolute Error (MAE): 22.141340104541953
# Mean Squared Error (MSE): 441.42169614450427
# Mean Absolute Error (MAE): 18.6694312186656
# Mean Squared Error (MSE): 540.4577651010951
# Mean Absolute Error (MAE): 19.990855799498835
# Mean Squared Error (MSE): 205.35977160465393
# Mean Absolute Error (MAE): 10.775701701227998

# %%
## B. The Test Set

# %%
# Create Pandas Dataframe
y_test = pd.DataFrame()
X_test = pd.DataFrame()

X_test = pd.get_dummies(df_lac_test['state'], drop_first=True)

# Add other variables
dict_var = ['ranking', 'hbcu', 'pct_retention', 'stu_faculty_ratio', 
              'beg_endowment', 'stu_financial_aid', 'stu_diversity', 'prop_major', 
              'pct_female_stu', 'pct_male_stu', 'gradrate_female', 'gradrate_male', 
              'pct_female_prof_salary', 'pct_male_prof_salary', 'uni_name']

for var in dict_var:
    X_test[var] = df_lac_test[var]
    
X_test = sm.add_constant(X_test)

# %%
### Predict the stu_diversity in 2021-2022 for Dickinson College

# %%
# Filter the school name
X_test = X_test[X_test['uni_name']=='Dickinson College']

X_test.drop('uni_name', axis=1, inplace=True)

# %%
# Target variable
y_test = df_lac_test[['prof_diversity', 'uni_name']]

# Filter the school name
y_test = y_test[y_test['uni_name']=='Dickinson College']

# Drop unnecessary column
y_test = y_test.drop('uni_name', axis=1)

# %%
# Predict the value
y_pred = model.predict(X_test)

# %%
# Filter the school name
df_harvard_test = df_lac_test[df_lac_test['uni_name']=='Dickinson College']

# %%
# Compare the actual and predicted values
df_concat = pd.concat([df_harvard_test, y_pred], axis=1)

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# View df
df_concat.head()
# Out:
#       ipeds_id           uni_name state school_year  ranking  hbcu  \
# 5007  212009.0  Dickinson College    PA   2021-2022       47   0.0
# 5008  212009.0  Dickinson College    PA   2021-2022       47   0.0
# 5009  212009.0  Dickinson College    PA   2021-2022       47   0.0
# 5010  212009.0  Dickinson College    PA   2021-2022       47   0.0
# 5011  212009.0  Dickinson College    PA   2021-2022       47   0.0
#
#       pct_retention  stu_faculty_ratio  beg_endowment  end_endowment  \
# 5007           92.0                9.0    600038947.0    583477014.0
# 5008           92.0                9.0    600038947.0    583477014.0
# 5009           92.0                9.0    600038947.0    583477014.0
# 5010           92.0                9.0    600038947.0    583477014.0
# 5011           92.0                9.0    600038947.0    583477014.0
#
#       stu_financial_aid  stu_diversity  prof_diversity    major  prop_major  \
# 5007             2173.0        36.1446         23.7443  11.0701      1.5625
# 5008             2173.0        36.1446         23.7443  13.0901      1.9531
# 5009             2173.0        36.1446         23.7443  16.0301      0.2344
# 5010             2173.0        36.1446         23.7443  16.0302      0.0000
# 5011             2173.0        36.1446         23.7443  16.0402      0.5469
#
#       pct_female_stu  pct_male_stu  pct_aian_stu  pct_asia_stu  pct_bkaa_stu  \
# 5007         58.1883       41.8117        0.0892        4.5515        5.2655
# 5008         58.1883       41.8117        0.0892        4.5515        5.2655
# 5009         58.1883       41.8117        0.0892        4.5515        5.2655
# 5010         58.1883       41.8117        0.0892        4.5515        5.2655
# 5011         58.1883       41.8117        0.0892        4.5515        5.2655
#
#       pct_hisp_stu  pct_nhpi_stu  pct_whit_stu  pct_2mor_stu  pct_unkn_stu  \
# 5007         8.166           0.0       63.8554        4.1053        0.9817
# 5008         8.166           0.0       63.8554        4.1053        0.9817
# 5009         8.166           0.0       63.8554        4.1053        0.9817
# 5010         8.166           0.0       63.8554        4.1053        0.9817
# 5011         8.166           0.0       63.8554        4.1053        0.9817
#
#       pct_intl_stu  pct_female_prof  pct_male_prof  pct_aian_prof  \
# 5007       12.9853           52.968         47.032         0.4566
# 5008       12.9853           52.968         47.032         0.4566
# 5009       12.9853           52.968         47.032         0.4566
# 5010       12.9853           52.968         47.032         0.4566
# 5011       12.9853           52.968         47.032         0.4566
#
#       pct_asia_prof  pct_bkaa_prof  pct_hisp_prof  pct_nhpi_prof  \
# 5007         5.0228          3.653         5.9361            0.0
# 5008         5.0228          3.653         5.9361            0.0
# 5009         5.0228          3.653         5.9361            0.0
# 5010         5.0228          3.653         5.9361            0.0
# 5011         5.0228          3.653         5.9361            0.0
#
#       pct_whit_prof  pct_2mor_prof  pct_unkn_prof  pct_intl_prof  \
# 5007        76.2557         0.9132         0.9132         6.8493
# 5008        76.2557         0.9132         0.9132         6.8493
# 5009        76.2557         0.9132         0.9132         6.8493
# 5010        76.2557         0.9132         0.9132         6.8493
# 5011        76.2557         0.9132         0.9132         6.8493
#
#       gradrate_female  gradrate_male  gradrate_aian  gradrate_asia  \
# 5007          60.4895        39.5105            0.0         3.8462
# 5008          60.4895        39.5105            0.0         3.8462
# 5009          60.4895        39.5105            0.0         3.8462
# 5010          60.4895        39.5105            0.0         3.8462
# 5011          60.4895        39.5105            0.0         3.8462
#
#       gradrate_bkaa  gradrate_hisp  gradrate_nhpi  gradrate_whit  \
# 5007         3.4965         7.5175            0.0        68.7063
# 5008         3.4965         7.5175            0.0        68.7063
# 5009         3.4965         7.5175            0.0        68.7063
# 5010         3.4965         7.5175            0.0        68.7063
# 5011         3.4965         7.5175            0.0        68.7063
#
#       gradrate_2mor  gradrate_unkn  gradrate_intl  pct_female_prof_salary  \
# 5007         3.8462         0.8741        11.7133                0.494567
# 5008         3.8462         0.8741        11.7133                0.494567
# 5009         3.8462         0.8741        11.7133                0.494567
# 5010         3.8462         0.8741        11.7133                0.494567
# 5011         3.8462         0.8741        11.7133                0.494567
#
#       pct_male_prof_salary          0
# 5007              0.505433  23.416245
# 5008              0.505433  23.412935
# 5009              0.505433  23.427500
# 5010              0.505433  23.429486
# 5011              0.505433  23.424851

# %%
# Calculate MSE
print("Mean Squared Error (MSE):", mean_squared_error(y_test, y_pred))

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 0.11412846255461657

# %%
# Calculate the Mean Absolute Error (MAE)
print("Mean Absolute Error (MAE):", mean_absolute_error(y_test, y_pred))

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 0.33246837013500513

# %%
# III. Calculate MSE Sorted by University Ranking Percentile

# %%
# Create df_ranking dataframe
df_ranking = pd.DataFrame()
df_ranking = df_lac_test.copy() # Remove the duplicates
df_ranking_test = df_lac_test.copy()

# %%
# Drop duplicates
df_ranking = df_ranking.drop_duplicates(subset=['uni_name', 'ranking'], keep='last')

# %%
# Keep necessary columns
df_ranking = df_ranking[['uni_name', 'ranking']]

# %%
# Define the percentiles
percentiles = [0, 25, 50, 75, 100]

# Calculate the percentiles
ranking_percentiles = np.percentile(df_ranking['ranking'], percentiles)

# Print the percentile values
print(ranking_percentiles)

# %%
# Define the percentile ranges
percentile_bins = [ranking_percentiles[0], ranking_percentiles[1], ranking_percentiles[2], ranking_percentiles[3], ranking_percentiles[4]]
percentile_labels = ['0th-25th', '25th-50th', '50th-75th', '75th-100th']

# Use pandas.cut() to categorize each university based on their ranking
df_ranking['ranking_percentile'] = pd.cut(df_ranking['ranking'], bins=percentile_bins, labels=percentile_labels, include_lowest=True)

# Use pandas.cut() to categorize each university based on their ranking
df_ranking_test['ranking_percentile'] = pd.cut(df_ranking_test['ranking'], bins=percentile_bins, labels=percentile_labels, include_lowest=True)

# View df
df_ranking[['uni_name', 'ranking', 'ranking_percentile']].sort_values('ranking')
# Out:
#                                        uni_name  ranking ranking_percentile
# 2779                           Williams College        1           0th-25th
# 2334                            Amherst College        2           0th-25th
# 5740                         Swarthmore College        3           0th-25th
# 2686                          Wellesley College        4           0th-25th
# 319                              Pomona College        4           0th-25th
# 2135                            Bowdoin College        6           0th-25th
# 145                   Claremont McKenna College        6           0th-25th
# 6802              Washington and Lee University        9           0th-25th
# 3026                           Carleton College        9           0th-25th
# 6351                         Middlebury College        9           0th-25th
# 3747                           Hamilton College        9           0th-25th
# 3704                         Colgate University       10           0th-25th
# 4112                             Vassar College       13           0th-25th
# 1759                           Grinnell College       13           0th-25th
# 2185                              Colby College       15           0th-25th
# 4175                           Davidson College       15           0th-25th
# 2573                              Smith College       15           0th-25th
# 5254                          Haverford College       15           0th-25th
# 647                         Wesleyan University       20           0th-25th
# 3649                            Barnard College       22           0th-25th
# 6656                     University of Richmond       22           0th-25th
# 2090                              Bates College       22           0th-25th
# 169                         Harvey Mudd College       25           0th-25th
# 499                            Colorado College       25           0th-25th
# 3164                         Macalester College       27           0th-25th
# 4448                             Kenyon College       28           0th-25th
# 4938                          Bryn Mawr College       28           0th-25th
# 7162                 Soka University of America       28           0th-25th
# 384                             Scripps College       28           0th-25th
# 1953                              Berea College       33           0th-25th
# 5006                        Bucknell University       34           0th-25th
# 2497                      Mount Holyoke College       34           0th-25th
# 4499                            Oberlin College       36           0th-25th
# 2446                  College of the Holy Cross       36           0th-25th
# 266                              Pitzer College       36           0th-25th
# 3955                           Skidmore College       36           0th-25th
# 386                      Thomas Aquinas College       40           0th-25th
# 5374                          Lafayette College       40           0th-25th
# 205                          Occidental College       40           0th-25th
# 5162              Franklin and Marshall College       43           0th-25th
# 597                             Trinity College       44           0th-25th
# 4412                         Denison University       44           0th-25th
# 4063                              Union College       44           0th-25th
# 6081                The University of the South       47          25th-50th
# 1383                          DePauw University       47          25th-50th
# 6920                            Whitman College       47          25th-50th
# 5054                          Dickinson College       47          25th-50th
# 547                         Connecticut College       51          25th-50th
# 1982                             Centre College       52          25th-50th
# 5925                          Furman University       52          25th-50th
# 5207                         Gettysburg College       54          25th-50th
# 2896                          Hillsdale College       54          25th-50th
# 1581                             Wabash College       54          25th-50th
# 3577                               Bard College       54          25th-50th
# 871                             Spelman College       54          25th-50th
# 6041                             Rhodes College       54          25th-50th
# 3912                     St Lawrence University       54          25th-50th
# 1327                            Wheaton College       61          25th-50th
# 738                         Agnes Scott College       61          25th-50th
# 4800                               Reed College       63          25th-50th
# 3914                     Sarah Lawrence College       63          25th-50th
# 2262                         St. John's College       63          25th-50th
# 7026                        Lawrence University       63          25th-50th
# 3328                            St Olaf College       67          25th-50th
# 2989                          Kalamazoo College       67          25th-50th
# 6764                Virginia Military Institute       69          25th-50th
# 4675                     The College of Wooster       69          25th-50th
# 5997                            Wofford College       69          25th-50th
# 3833              Hobart William Smith Colleges       72          25th-50th
# 5516                         Muhlenberg College       72          25th-50th
# 1157                               Knox College       72          25th-50th
# 4850                      Willamette University       72          25th-50th
# 7154                         St. John's College       76          25th-50th
# 1727                            Cornell College       76          25th-50th
# 6295                         Bennington College       76          25th-50th
# 4705                      Lewis & Clark College       76          25th-50th
# 6980                             Beloit College       80          25th-50th
# 4899                          Allegheny College       80          25th-50th
# 1064               Illinois Wesleyan University       80          25th-50th
# 2260             St. Mary's College of Maryland       80          25th-50th
# 7160                     New College of Florida       84          25th-50th
# 1196                        Lake Forest College       84          25th-50th
# 3122                  Gustavus Adolphus College       84          25th-50th
# 1430                            Earlham College       84          25th-50th
# 2024                    Transylvania University       84          25th-50th
# 2740            Wheaton College (Massachusetts)       84          25th-50th
# 5334                            Juniata College       84          25th-50th
# 6853                  University of Puget Sound       84          25th-50th
# 5783                            Ursinus College       84          25th-50th
# 4579                   Ohio Wesleyan University       93          50th-75th
# 1283                          Principia College       93          50th-75th
# 87                              Hendrix College       93          50th-75th
# 2294                         Washington College       96          50th-75th
# 1553                       Saint Mary's College       96          50th-75th
# 3238                  College of Saint Benedict       96          50th-75th
# 1014                          Augustana College       96          50th-75th
# 5816             Washington & Jefferson College       96          50th-75th
# 2051                    College of the Atlantic      101          50th-75th
# 6530                         Hollins University      102          50th-75th
# 6573                     Randolph-Macon College      102          50th-75th
# 6500                     Hampden-Sydney College      102          50th-75th
# 6163                    Southwestern University      102          50th-75th
# 6124                             Austin College      102          50th-75th
# 3527                       Saint Anselm College      102          50th-75th
# 1807                             Luther College      102          50th-75th
# 1514                            Hanover College      102          50th-75th
# 450                            Whittier College      102          50th-75th
# 3276                     Saint Johns University      102          50th-75th
# 2960                               Hope College      112          50th-75th
# 416                            Westmont College      113          50th-75th
# 5635                     Susquehanna University      113          50th-75th
# 2628                          Stonehill College      113          50th-75th
# 3569                            Drew University      113          50th-75th
# 5120                      Elizabethtown College      113          50th-75th
# 3366                           Millsaps College      113          50th-75th
# 5863                        Westminster College      120          50th-75th
# 2230                            Goucher College      120          50th-75th
# 6395                    Saint Michael's College      120          50th-75th
# 5431                           Lycoming College      120          50th-75th
# 938                        The College of Idaho      120          50th-75th
# 4764     Linfield University-McMinnville Campus      120          50th-75th
# 7065                              Ripon College      120          50th-75th
# 5967                       Presbyterian College      127          50th-75th
# 1244                           Monmouth College      127          50th-75th
# 3874                           Houghton College      127          50th-75th
# 7129                      Saint Norbert College      130         75th-100th
# 6710                            Roanoke College      130         75th-100th
# 2856                             Albion College      130         75th-100th
# 3071              Concordia College at Moorhead      130         75th-100th
# 1666                                Coe College      130         75th-100th
# 31                  Birmingham-Southern College      130         75th-100th
# 704                              Eckerd College      136         75th-100th
# 4138                              Wells College      136         75th-100th
# 1474                           Franklin College      136         75th-100th
# 4272                           Meredith College      136         75th-100th
# 6603                           Randolph College      140         75th-100th
# 767                            Covenant College      140         75th-100th
# 1618                            Central College      140         75th-100th
# 1111                           Illinois College      140         75th-100th
# 4342                              Salem College      140         75th-100th
# 4307  University of North Carolina at Asheville      140         75th-100th
# 5571                      Saint Vincent College      140         75th-100th
# 5472                        Moravian University      140         75th-100th
# 3200             University of Minnesota-Morris      140         75th-100th
# 2521      Massachusetts College of Liberal Arts      149         75th-100th
# 905                            Wesleyan College      149         75th-100th
# 1859                            Simpson College      149         75th-100th
# 3783                           Hartwick College      149         75th-100th
# 4623                      Wittenberg University      153         75th-100th
# 6471                      Emory & Henry College      154         75th-100th
# 2049             Centenary College of Louisiana      155         75th-100th
# 2391                             Gordon College      155         75th-100th
# 3429                        Westminster College      155         75th-100th
# 4220                           Guilford College      155         75th-100th
# 4013                   SUNY at Purchase College      155         75th-100th
# 802                           Morehouse College      155         75th-100th
# 1907                           Wartburg College      162         75th-100th
# 6737                        Sweet Briar College      162         75th-100th
# 4365                      Warren Wilson College      162         75th-100th
# 4862       Bryn Athyn College of the New Church      162         75th-100th
# 835                       Oglethorpe University      166         75th-100th
# 3477                           Doane University      166         75th-100th
# 7152            University of Puerto Rico-Cayey      166         75th-100th
# 57                                 Lyon College      166         75th-100th
# 6749   University of Virginia's College at Wise      166         75th-100th

# %%
## A. 0th-25th percentile: Top-performing universities

# %%
# Create Pandas Dataframe
y_test_top = pd.DataFrame()
X_test_top = pd.DataFrame()

X_test_top = pd.get_dummies(df_ranking_test['state'], drop_first=True)

# Add other variables
dict_var = ['ranking', 'hbcu', 'pct_retention', 'stu_faculty_ratio', 
              'beg_endowment', 'stu_financial_aid', 'prof_diversity', 'prop_major', 
              'pct_female_stu', 'pct_male_stu', 'gradrate_female', 'gradrate_male', 
              'pct_female_prof_salary', 'pct_male_prof_salary', 'ranking_percentile']

for var in dict_var:
    X_test_top[var] = df_ranking_test[var]
    
X_test_top = sm.add_constant(X_test_top)

# %%
# Filter the top universities
X_test_top = X_test_top[X_test_top['ranking_percentile']=='0th-25th']

# Drop unnecessary column
X_test_top = X_test_top.drop('ranking_percentile', axis=1)

# %%
# Target variable
y_test_top = df_ranking_test[['stu_diversity', 'ranking_percentile']]

# Filter the school name
y_test_top = y_test_top[y_test_top['ranking_percentile']=='0th-25th']

# Drop unnecessary column
y_test_top = y_test_top.drop('ranking_percentile', axis=1)

# %%
# Predict the value
y_pred_top = model.predict(X_test_top)

# %%
# Calculate MSE
print("Mean Squared Error (MSE):", mean_squared_error(y_test_top, y_pred_top))

# %%
# Calculate the Mean Absolute Error (MAE)
print("Mean Absolute Error (MAE):", mean_absolute_error(y_test_top, y_pred_top))

# %%
## B. 25th-50th percentile: High-performing universities, but not at the top

# %%
# Create Pandas Dataframe
y_test_high = pd.DataFrame()
X_test_high = pd.DataFrame()

X_test_high = pd.get_dummies(df_ranking_test['state'], drop_first=True)

# Add other variables
dict_var = ['ranking', 'hbcu', 'pct_retention', 'stu_faculty_ratio', 
              'beg_endowment', 'stu_financial_aid', 'prof_diversity', 'prop_major', 
              'pct_female_stu', 'pct_male_stu', 'gradrate_female', 'gradrate_male', 
              'pct_female_prof_salary', 'pct_male_prof_salary', 'ranking_percentile']

for var in dict_var:
    X_test_high[var] = df_ranking_test[var]
    
X_test_high = sm.add_constant(X_test_high)

# %%
# Filter the top universities
X_test_high = X_test_high[X_test_high['ranking_percentile']=='25th-50th']

# Drop unnecessary column
X_test_high = X_test_high.drop('ranking_percentile', axis=1)

# %%
# Target variable
y_test_high = df_ranking_test[['stu_diversity', 'ranking_percentile']]

# Filter the school name
y_test_high = y_test_high[y_test_high['ranking_percentile']=='25th-50th']

# Drop unnecessary column
y_test_high = y_test_high.drop('ranking_percentile', axis=1)

# %%
# Predict the value
y_pred_high = model.predict(X_test_high)

# %%
# Calculate MSE
print("Mean Squared Error (MSE):", mean_squared_error(y_test_high, y_pred_high))

# %%
# Calculate the Mean Absolute Error (MAE)
print("Mean Absolute Error (MAE):", mean_absolute_error(y_test_high, y_pred_high))

# %%
## C. 50th-75th percentile: Mid-range universities

# %%
# Create Pandas Dataframe
y_test_mid = pd.DataFrame()
X_test_mid = pd.DataFrame()

X_test_mid = pd.get_dummies(df_ranking_test['state'], drop_first=True)

# Add other variables
dict_var = ['ranking', 'hbcu', 'pct_retention', 'stu_faculty_ratio', 
              'beg_endowment', 'stu_financial_aid', 'prof_diversity', 'prop_major', 
              'pct_female_stu', 'pct_male_stu', 'gradrate_female', 'gradrate_male', 
              'pct_female_prof_salary', 'pct_male_prof_salary', 'ranking_percentile']

for var in dict_var:
    X_test_mid[var] = df_ranking_test[var]
    
X_test_mid = sm.add_constant(X_test_mid)

# %%
# Filter the top universities
X_test_mid = X_test_mid[X_test_mid['ranking_percentile']=='50th-75th']

# Drop unnecessary column
X_test_mid = X_test_mid.drop('ranking_percentile', axis=1)

# %%
# Target variable
y_test_mid = df_ranking_test[['stu_diversity', 'ranking_percentile']]

# Filter the school name
y_test_mid = y_test_mid[y_test_mid['ranking_percentile']=='50th-75th']

# Drop unnecessary column
y_test_mid = y_test_mid.drop('ranking_percentile', axis=1)

# %%
# Predict the value
y_pred_mid = model.predict(X_test_mid)

# %%
# Calculate MSE
print("Mean Squared Error (MSE):", mean_squared_error(y_test_mid, y_pred_mid))

# %%
# Calculate the Mean Absolute Error (MAE)
print("Mean Absolute Error (MAE):", mean_absolute_error(y_test_mid, y_pred_mid))

# %%
## D. 75th-100th percentile: Lower-performing universities relative to the dataset

# %%
# Create Pandas Dataframe
y_test_low = pd.DataFrame()
X_test_low = pd.DataFrame()

X_test_low = pd.get_dummies(df_ranking_test['state'], drop_first=True)

# Add other variables
dict_var = ['ranking', 'hbcu', 'pct_retention', 'stu_faculty_ratio', 
              'beg_endowment', 'stu_financial_aid', 'prof_diversity', 'prop_major', 
              'pct_female_stu', 'pct_male_stu', 'gradrate_female', 'gradrate_male', 
              'pct_female_prof_salary', 'pct_male_prof_salary', 'ranking_percentile']

for var in dict_var:
    X_test_low[var] = df_ranking_test[var]
    
X_test_low = sm.add_constant(X_test_low)

# %%
# Filter the top universities
X_test_low = X_test_low[X_test_low['ranking_percentile']=='75th-100th']

# Drop unnecessary column
X_test_low = X_test_low.drop('ranking_percentile', axis=1)

# %%
# Target variable
y_test_low = df_ranking_test[['prof_diversity', 'ranking_percentile']]

# Filter the school name
y_test_low = y_test_low[y_test_low['ranking_percentile']=='75th-100th']

# Drop unnecessary column
y_test_low = y_test_low.drop('ranking_percentile', axis=1)

# %%
# Predict the value
y_pred_low = model.predict(X_test_low)

# %%
# Calculate MSE
print("Mean Squared Error (MSE):", mean_squared_error(y_test_low, y_pred_low))

# %%
# Calculate the Mean Absolute Error (MAE)
print("Mean Absolute Error (MAE):", mean_absolute_error(y_test_low, y_pred_low))

# %%
## Visualizations

# %%
# View df
df_ranking = df_ranking[['uni_name', 'ranking', 'ranking_percentile']].sort_values('ranking')
df_ranking
# Out:
#                                        uni_name  ranking ranking_percentile
# 2779                           Williams College        1           0th-25th
# 2334                            Amherst College        2           0th-25th
# 5740                         Swarthmore College        3           0th-25th
# 2686                          Wellesley College        4           0th-25th
# 319                              Pomona College        4           0th-25th
# 2135                            Bowdoin College        6           0th-25th
# 145                   Claremont McKenna College        6           0th-25th
# 6802              Washington and Lee University        9           0th-25th
# 3026                           Carleton College        9           0th-25th
# 6351                         Middlebury College        9           0th-25th
# 3747                           Hamilton College        9           0th-25th
# 3704                         Colgate University       10           0th-25th
# 4112                             Vassar College       13           0th-25th
# 1759                           Grinnell College       13           0th-25th
# 2185                              Colby College       15           0th-25th
# 4175                           Davidson College       15           0th-25th
# 2573                              Smith College       15           0th-25th
# 5254                          Haverford College       15           0th-25th
# 647                         Wesleyan University       20           0th-25th
# 3649                            Barnard College       22           0th-25th
# 6656                     University of Richmond       22           0th-25th
# 2090                              Bates College       22           0th-25th
# 169                         Harvey Mudd College       25           0th-25th
# 499                            Colorado College       25           0th-25th
# 3164                         Macalester College       27           0th-25th
# 4448                             Kenyon College       28           0th-25th
# 4938                          Bryn Mawr College       28           0th-25th
# 7162                 Soka University of America       28           0th-25th
# 384                             Scripps College       28           0th-25th
# 1953                              Berea College       33           0th-25th
# 5006                        Bucknell University       34           0th-25th
# 2497                      Mount Holyoke College       34           0th-25th
# 4499                            Oberlin College       36           0th-25th
# 2446                  College of the Holy Cross       36           0th-25th
# 266                              Pitzer College       36           0th-25th
# 3955                           Skidmore College       36           0th-25th
# 386                      Thomas Aquinas College       40           0th-25th
# 5374                          Lafayette College       40           0th-25th
# 205                          Occidental College       40           0th-25th
# 5162              Franklin and Marshall College       43           0th-25th
# 597                             Trinity College       44           0th-25th
# 4412                         Denison University       44           0th-25th
# 4063                              Union College       44           0th-25th
# 6081                The University of the South       47          25th-50th
# 1383                          DePauw University       47          25th-50th
# 6920                            Whitman College       47          25th-50th
# 5054                          Dickinson College       47          25th-50th
# 547                         Connecticut College       51          25th-50th
# 1982                             Centre College       52          25th-50th
# 5925                          Furman University       52          25th-50th
# 5207                         Gettysburg College       54          25th-50th
# 2896                          Hillsdale College       54          25th-50th
# 1581                             Wabash College       54          25th-50th
# 3577                               Bard College       54          25th-50th
# 871                             Spelman College       54          25th-50th
# 6041                             Rhodes College       54          25th-50th
# 3912                     St Lawrence University       54          25th-50th
# 1327                            Wheaton College       61          25th-50th
# 738                         Agnes Scott College       61          25th-50th
# 4800                               Reed College       63          25th-50th
# 3914                     Sarah Lawrence College       63          25th-50th
# 2262                         St. John's College       63          25th-50th
# 7026                        Lawrence University       63          25th-50th
# 3328                            St Olaf College       67          25th-50th
# 2989                          Kalamazoo College       67          25th-50th
# 6764                Virginia Military Institute       69          25th-50th
# 4675                     The College of Wooster       69          25th-50th
# 5997                            Wofford College       69          25th-50th
# 3833              Hobart William Smith Colleges       72          25th-50th
# 5516                         Muhlenberg College       72          25th-50th
# 1157                               Knox College       72          25th-50th
# 4850                      Willamette University       72          25th-50th
# 7154                         St. John's College       76          25th-50th
# 1727                            Cornell College       76          25th-50th
# 6295                         Bennington College       76          25th-50th
# 4705                      Lewis & Clark College       76          25th-50th
# 6980                             Beloit College       80          25th-50th
# 4899                          Allegheny College       80          25th-50th
# 1064               Illinois Wesleyan University       80          25th-50th
# 2260             St. Mary's College of Maryland       80          25th-50th
# 7160                     New College of Florida       84          25th-50th
# 1196                        Lake Forest College       84          25th-50th
# 3122                  Gustavus Adolphus College       84          25th-50th
# 1430                            Earlham College       84          25th-50th
# 2024                    Transylvania University       84          25th-50th
# 2740            Wheaton College (Massachusetts)       84          25th-50th
# 5334                            Juniata College       84          25th-50th
# 6853                  University of Puget Sound       84          25th-50th
# 5783                            Ursinus College       84          25th-50th
# 4579                   Ohio Wesleyan University       93          50th-75th
# 1283                          Principia College       93          50th-75th
# 87                              Hendrix College       93          50th-75th
# 2294                         Washington College       96          50th-75th
# 1553                       Saint Mary's College       96          50th-75th
# 3238                  College of Saint Benedict       96          50th-75th
# 1014                          Augustana College       96          50th-75th
# 5816             Washington & Jefferson College       96          50th-75th
# 2051                    College of the Atlantic      101          50th-75th
# 6530                         Hollins University      102          50th-75th
# 6573                     Randolph-Macon College      102          50th-75th
# 6500                     Hampden-Sydney College      102          50th-75th
# 6163                    Southwestern University      102          50th-75th
# 6124                             Austin College      102          50th-75th
# 3527                       Saint Anselm College      102          50th-75th
# 1807                             Luther College      102          50th-75th
# 1514                            Hanover College      102          50th-75th
# 450                            Whittier College      102          50th-75th
# 3276                     Saint Johns University      102          50th-75th
# 2960                               Hope College      112          50th-75th
# 416                            Westmont College      113          50th-75th
# 5635                     Susquehanna University      113          50th-75th
# 2628                          Stonehill College      113          50th-75th
# 3569                            Drew University      113          50th-75th
# 5120                      Elizabethtown College      113          50th-75th
# 3366                           Millsaps College      113          50th-75th
# 5863                        Westminster College      120          50th-75th
# 2230                            Goucher College      120          50th-75th
# 6395                    Saint Michael's College      120          50th-75th
# 5431                           Lycoming College      120          50th-75th
# 938                        The College of Idaho      120          50th-75th
# 4764     Linfield University-McMinnville Campus      120          50th-75th
# 7065                              Ripon College      120          50th-75th
# 5967                       Presbyterian College      127          50th-75th
# 1244                           Monmouth College      127          50th-75th
# 3874                           Houghton College      127          50th-75th
# 7129                      Saint Norbert College      130         75th-100th
# 6710                            Roanoke College      130         75th-100th
# 2856                             Albion College      130         75th-100th
# 3071              Concordia College at Moorhead      130         75th-100th
# 1666                                Coe College      130         75th-100th
# 31                  Birmingham-Southern College      130         75th-100th
# 704                              Eckerd College      136         75th-100th
# 4138                              Wells College      136         75th-100th
# 1474                           Franklin College      136         75th-100th
# 4272                           Meredith College      136         75th-100th
# 6603                           Randolph College      140         75th-100th
# 767                            Covenant College      140         75th-100th
# 1618                            Central College      140         75th-100th
# 1111                           Illinois College      140         75th-100th
# 4342                              Salem College      140         75th-100th
# 4307  University of North Carolina at Asheville      140         75th-100th
# 5571                      Saint Vincent College      140         75th-100th
# 5472                        Moravian University      140         75th-100th
# 3200             University of Minnesota-Morris      140         75th-100th
# 2521      Massachusetts College of Liberal Arts      149         75th-100th
# 905                            Wesleyan College      149         75th-100th
# 1859                            Simpson College      149         75th-100th
# 3783                           Hartwick College      149         75th-100th
# 4623                      Wittenberg University      153         75th-100th
# 6471                      Emory & Henry College      154         75th-100th
# 2049             Centenary College of Louisiana      155         75th-100th
# 2391                             Gordon College      155         75th-100th
# 3429                        Westminster College      155         75th-100th
# 4220                           Guilford College      155         75th-100th
# 4013                   SUNY at Purchase College      155         75th-100th
# 802                           Morehouse College      155         75th-100th
# 1907                           Wartburg College      162         75th-100th
# 6737                        Sweet Briar College      162         75th-100th
# 4365                      Warren Wilson College      162         75th-100th
# 4862       Bryn Athyn College of the New Church      162         75th-100th
# 835                       Oglethorpe University      166         75th-100th
# 3477                           Doane University      166         75th-100th
# 7152            University of Puerto Rico-Cayey      166         75th-100th
# 57                                 Lyon College      166         75th-100th
# 6749   University of Virginia's College at Wise      166         75th-100th

# %%
df_ranking_top = df_ranking[df_ranking['ranking_percentile']=='0th-25th'].head()

# %%
df_ranking_high = df_ranking[df_ranking['ranking_percentile']=='25th-50th'].head()

# %%
df_ranking_mid = df_ranking[df_ranking['ranking_percentile']=='50th-75th'].head()

# %%
df_ranking_low = df_ranking[df_ranking['ranking_percentile']=='75th-100th'].head()

# %%
# Create the Dataframe to display MSE and uni
df_mse = {}

df_mse = {
    'Top-performing universities': mean_squared_error(y_test_top, y_pred_top),
    'High-performing universities': mean_squared_error(y_test_high, y_pred_high),
    'Mid-range universities': mean_squared_error(y_test_mid, y_pred_mid),
    'Lower-performing universities': mean_squared_error(y_test_low, y_pred_low)
}

# Convert the dictionary to a DataFrame
df_mse = pd.DataFrame(list(df_mse.items()), columns=['uni_rank', 'MSE'])

# Matching
df_mse['ranking_percentile'] = np.select(
    [
        df_mse['uni_rank'] == 'Top-performing universities', 
        df_mse['uni_rank'] == 'High-performing universities', 
        df_mse['uni_rank'] == 'Mid-range universities', 
        df_mse['uni_rank'] == 'Lower-performing universities'
    ],
    ['0th-25th', '25th-50th', '50th-75th', '75th-100th'],
    default='Unknown'
)

# View df
df_mse
# Out:
#                         uni_rank         MSE ranking_percentile
# 0    Top-performing universities  635.282151           0th-25th
# 1   High-performing universities  441.421696          25th-50th
# 2         Mid-range universities  540.457765          50th-75th
# 3  Lower-performing universities  205.359772         75th-100th

# %%
# Concat df
df_nu_ranking = pd.concat([df_ranking_top, df_ranking_high])
df_nu_ranking = pd.concat([df_nu_ranking, df_ranking_mid])
df_nu_ranking = pd.concat([df_nu_ranking, df_ranking_low])
df_merged = pd.merge(df_nu_ranking, df_mse, on='ranking_percentile', how='left')

# %%
# Drop unncessary column
df_merged = df_merged.drop('ranking_percentile', axis=1)

# View df
df_merged
# Out:
#                          uni_name  ranking                       uni_rank  \
# 0                Williams College        1    Top-performing universities
# 1                 Amherst College        2    Top-performing universities
# 2              Swarthmore College        3    Top-performing universities
# 3               Wellesley College        4    Top-performing universities
# 4                  Pomona College        4    Top-performing universities
# 5     The University of the South       47   High-performing universities
# 6               DePauw University       47   High-performing universities
# 7                 Whitman College       47   High-performing universities
# 8               Dickinson College       47   High-performing universities
# 9             Connecticut College       51   High-performing universities
# 10       Ohio Wesleyan University       93         Mid-range universities
# 11              Principia College       93         Mid-range universities
# 12                Hendrix College       93         Mid-range universities
# 13             Washington College       96         Mid-range universities
# 14           Saint Mary's College       96         Mid-range universities
# 15          Saint Norbert College      130  Lower-performing universities
# 16                Roanoke College      130  Lower-performing universities
# 17                 Albion College      130  Lower-performing universities
# 18  Concordia College at Moorhead      130  Lower-performing universities
# 19                    Coe College      130  Lower-performing universities
#
#            MSE
# 0   635.282151
# 1   635.282151
# 2   635.282151
# 3   635.282151
# 4   635.282151
# 5   441.421696
# 6   441.421696
# 7   441.421696
# 8   441.421696
# 9   441.421696
# 10  540.457765
# 11  540.457765
# 12  540.457765
# 13  540.457765
# 14  540.457765
# 15  205.359772
# 16  205.359772
# 17  205.359772
# 18  205.359772
# 19  205.359772

# %%
# Export to excel
df_merged.to_excel('df_mse_percentile_prof_diversity.xlsx', index=False)

# %%
# Sort by MSE
df_sorted = df_merged.copy()

# Plotting the line chart with values displayed on the line
plt.figure(figsize=(8, 6))
plt.plot(df_sorted['uni_rank'], df_sorted['MSE'], marker='o', linestyle='-', color='b')

# Annotating the values on the line
for i, mse in enumerate(df_sorted['MSE']):
    plt.text(df_sorted['uni_rank'].iloc[i], mse, f'{mse:.4f}', ha='center', va='bottom', fontsize=10)

plt.title('MSE Values for Professor Diversity Based on 2021-2022 Liberal Arts Rankings')
plt.xlabel('College Category')
plt.ylabel('MSE')
plt.xticks(rotation=20, ha='right')
plt.grid(True)
plt.tight_layout()

# Save the figure as a PNG file with higher DPI
plt.savefig(f'MSE Values for Professor Diversity Based on 2021-2022 Liberal Arts Rankings.png', format='png', dpi=300)

# Show the plot
plt.show()
